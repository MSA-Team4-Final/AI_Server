# %%
from dotenv import load_dotenv  # 추가

# .env 파일 로드
load_dotenv()
# Out:
# True

# %%
# single_turn.py
import google.generativeai as genai
import os
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
model = genai.GenerativeModel('gemini-2.0-flash')
response = model.generate_content("인공지능에 대해 한 문장으로 설명하세요.")

# %%
print(response.text)
# Out:
# 인공지능은 컴퓨터가 인간의 지능적인 기능을 수행하도록 만드는 기술입니다.

# %%
# multi_turn1.py
import google.generativeai as genai
model = genai.GenerativeModel('gemini-2.0-flash')
chat_session = model.start_chat(history=[]) #ChatSession 객체 반환
user_queries = ["동물이란.", "사자도 거기 포함되나"]
for user_query in user_queries:
    print(f'[사용자]: {user_query}')
    response = chat_session.send_message(user_query)
    print(f'[모델]: {response.text}')
# Out:
# [사용자]: 동물이란.
# [모델]: 동물은 생물 분류학상 **동물계(Animalia)**에 속하는 진핵생물입니다. 식물, 균류 등 다른 생물계와 구별되는 뚜렷한 특징을 가지고 있습니다.
#
# **일반적인 동물의 특징:**
#
# *   **다세포 생물:** 대부분의 동물이 여러 개의 세포로 이루어져 있으며, 세포들이 모여 조직, 기관, 기관계를 구성합니다.
# *   **종속 영양 생물:** 스스로 양분을 만들지 못하고 다른 생물을 섭취하여 에너지를 얻습니다. (식물은 광합성을 통해 스스로 양분 생성)
# *   **운동성:** 대부분의 동물이 자유롭게 움직일 수 있습니다. (성체가 고착 생활을 하는 동물도 일부 존재)
# *   **신경계와 감각 기관:** 외부 자극에 반응하고 정보를 처리하는 신경계와 감각 기관을 가지고 있습니다.
# *   **유성 생식:** 대부분의 동물이 암수 생식 세포의 결합을 통해 번식합니다.
# *   **세포벽 없음:** 식물 세포와 달리 세포벽이 없습니다.
# *   **발생 과정:** 수정란이 세포 분열과 분화를 거쳐 개체로 발달하는 특유의 발생 과정을 거칩니다.
#
# **동물의 다양성:**
#
# 동물계는 매우 다양하며, 척추동물(어류, 양서류, 파충류, 조류, 포유류)과 무척추동물(곤충, 갑각류, 연체동물, 환형동물, 해면동물 등)로 크게 나눌 수 있습니다. 각각의 동물 그룹은 고유한 특징과 생태적 역할을 가지고 있습니다.
#
# **동물의 중요성:**
#
# 동물은 생태계에서 중요한 역할을 수행하며, 인간에게 식량, 의약품, 연구 자료 등 다양한 자원을 제공합니다. 또한, 동물의 아름다움과 행동은 인간에게 즐거움과 영감을 주기도 합니다.
#
# 더 궁금한 점이 있다면 언제든지 질문해주세요.
# [사용자]: 사자도 거기 포함되나
# [모델]: 네, 사자는 당연히 동물에 포함됩니다. 사자는 **포유류**에 속하며, 좀 더 구체적으로는 **고양이과** 동물입니다.
#
# *   **동물계(Animalia)**
#     *   **척삭동물문(Chordata)**
#         *   **포유강(Mammalia)**
#             *   **식육목(Carnivora)**
#                 *   **고양이과(Felidae)**
#                     *   **표범속(Panthera)**
#                         *   **사자(Panthera leo)**
#
# 위 분류 체계에서 보듯이, 사자는 동물계에서 가장 세부적인 종(species) 단계까지 분류된 동물입니다. 포유류의 특징인 젖을 먹여 새끼를 키우고, 털을 가지고 있으며, 따뜻한 피를 가진 정온동물입니다. 또한 고양이과의 특징인 날카로운 발톱과 이빨을 가지고 육식을 합니다.

# %%
# multi_turn2.py
import google.generativeai as genai

model = genai.GenerativeModel('gemini-2.0-flash')
user_queries = [{'role':'user', 'parts': ["동물이란."]},
                {'role':'user', 'parts': ["사자도 거기 포함되나"]}
            ]
history = []

for user_query in user_queries:
    history.append(user_query)
    print(f'[사용자]: {user_query["parts"][0]}')
    response = model.generate_content(history)
    print(f'[모델]: {response.text}')
    history.append(response.candidates[0].content)
# Out:
# [사용자]: 동물이란.
# [모델]: 동물은 생물 분류의 한 종류로, 일반적으로 다음과 같은 특징을 갖습니다.
#
# *   **진핵세포:** 세포 내에 핵을 포함한 복잡한 구조를 가집니다.
# *   **다세포:** 여러 개의 세포로 구성되어 있습니다.
# *   **종속영양:** 스스로 영양분을 만들지 못하고, 다른 생물을 섭취하여 에너지를 얻습니다.
# *   **운동성:** 대부분의 동물은 움직일 수 있습니다.
# *   **감각 및 신경계:** 외부 자극에 반응하고 정보를 처리하는 감각 기관과 신경계를 가지고 있습니다.
# *   **유성생식:** 대부분의 동물이 암수 생식세포의 결합을 통해 번식합니다.
#
# 동물은 지구상에서 매우 다양하게 존재하며, 척추동물(어류, 양서류, 파충류, 조류, 포유류)과 무척추동물(곤충, 갑각류, 연체동물, 환형동물 등)로 크게 나눌 수 있습니다.
#
# 더 자세한 정보가 필요하시면 어떤 점이 궁금하신지 알려주세요. 예를 들어, 특정 동물의 특징, 동물의 진화, 동물의 분류 등에 대해 질문하실 수 있습니다.
# [사용자]: 사자도 거기 포함되나
# [모델]: 네, 사자는 동물에 포함됩니다. 더 구체적으로 말씀드리면, 사자는 **포유류**에 속하는 동물입니다.
#
# 좀 더 자세한 분류는 다음과 같습니다:
#
# *   **계:** 동물계 (Animalia)
# *   **문:** 척삭동물문 (Chordata)
# *   **강:** 포유강 (Mammalia)
# *   **목:** 식육목 (Carnivora)
# *   **과:** 고양이과 (Felidae)
# *   **속:** 표범속 (Panthera)
# *   **종:** 사자 (Panthera leo)
#
# 사자는 포유류의 특징인 털, 젖을 먹여 새끼를 키우는 점, 폐호흡 등을 가지고 있습니다. 또한, 고양이과의 특징인 날카로운 발톱과 이빨, 뛰어난 사냥 능력 등을 가지고 있습니다.

# %%
# multi_turn1.py
for idx, content in enumerate(chat_session.history):
    print(f"{content.__class__.__name__}[{idx}]")
    print(content)
# Out:
# Content[0]
# parts {
#   text: "인공지능에 대해 한 문장으로 짧게 설명하세요."
# }
# role: "user"
#
# Content[1]
# parts {
#   text: "인공지능은 컴퓨터가 인간의 지능적인 행동을 모방하거나 수행할 수 있도록 하는 기술입니다.\n"
# }
# role: "model"
#
# Content[2]
# parts {
#   text: "의식이 있는지 한 문장으로 답하세요."
# }
# role: "user"
#
# Content[3]
# parts {
#   text: "저는 의식이 없습니다.\n"
# }
# role: "model"
